# %% [markdown]
# # BIOS512 Assignment #2

# %% [markdown]
# 📚 Import the `tidyverse` and the `palmerpenguins` packages. (**Hint:** use the `library` function)

# %%
library(tidyverse)
library(palmerpenguins)
library(scales)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘palmerpenguins’ was built under R version 4.1.3”
#
# Attaching package: ‘scales’
#
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# The following object is masked from ‘package:readr’:
#
#     col_factor

# %% [markdown]
# Use `geom_bar` to make a histogram of penguin counts by `year`.

# %%
options(repr.plot.height = 3, repr.plot.width = 4)

p = ggplot(penguins, aes(x = year)) + geom_bar(fill = 'steelblue', color = 'steelblue', alpha = 0.75) +
    labs(x = 'Year', y = 'Number of Peguins', title = 'Count of Penguins by Year')+
    theme_minimal() + theme(plot.title = element_text(size = 9, hjust = .5)) 
p
# Out:
# plot without title

# %% [markdown]
# Make a histogram or KDE plot that shows the distribution of body mass in each year. *Use a different theme than the default.*

# %%
options(repr.plot.height = 5, repr.plot.width = 5)
p_mass = ggplot(penguins, aes(x = body_mass_g)) + geom_histogram(fill = 'steelblue', color = 'steelblue', 
                alpha = 0.75, binwidth = 100, na.rm = TRUE) +
        facet_wrap(~year, ncol = 1) + scale_x_continuous(labels = comma_format()) +
        theme_minimal() + theme(plot.title = element_text(size = 9), 
                strip.text.x = element_text(face = 'bold', hjust = 1, color = '#63666A', size = 10), 
                                plot.margin = margin(t = 0, r = 1, b = 0, l = 0, unit = "cm"))  +
        labs(y = 'Number of Penguins', x = 'Body Mass in Grams') + 
        labs(title = "Histogram of Penguin Body Mass for Measurements taken from 2007-2009")
p_mass
# Out:
# plot without title

# %% [markdown]
# 🎉**BONUS**: can you adjust the `x-axis` labels to have "comma" formatting? (**Hint:** use the `comma_format()` function from the `scales` package.)

# %% [markdown]
# 👇 Here is the chart I made for reference.

# %% [markdown]
# <img src="https://github.com/chuckpr/BIOS512/blob/main/assignments/mass_histograms3.png?raw=true" style="width:700px" />

# %% [markdown]
# Is there a difference between the body mass of male and female penguins? Use a scatter plot with jitter to compare the masses of male and female penguins. **Facet by `species` to compare within each species-group.**

# %% [markdown]
# - Male Penguins are often larger than Female penguins
#     - Male and Female Chinstrap penguis are closer in size compared to other penguin species

# %%
options(repr.plot.height = 5, repr.plot.width = 4)
p_scat = ggplot(penguins, aes(y = sex, x = body_mass_g)) + geom_point(na.rm = TRUE, 
            position = position_jitter(height = 0.2, width = 0), size = 1, alpha = 0.5, color = '#63666A') +
        facet_wrap(~species, ncol = 1) + theme_minimal() + 
        theme(strip.text.x = element_text(face = 'bold', hjust = 0, color = '#63666A', size = 10)) +
        labs(x = 'Body Mass in Grams') + scale_x_continuous(labels = comma_format())

p_scat
# Out:
# plot without title

# %% [markdown]
# 👇 Here is my solution for reference.

# %% [markdown]
# <img src="https://github.com/chuckpr/BIOS512/blob/main/assignments/sex_differences_in_body_mass_within_species.png?raw=true" style="width: 600px" />
